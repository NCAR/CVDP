# %% [markdown]
# ![CVDP Banner](data:image/png;base64,...)
#
# ```
# Webpage: https://github.com/NCAR/CVDP/tree/main
# Version: CVDP 0.1
# Generation Timestamp: 2025-03-05 16:32
# Figures Generated: 1
# ```

# %% [markdown]
# ## Seasonal Ensemble Means

# %% [markdown]
# ![Figure](data:image/png;base64,...)
